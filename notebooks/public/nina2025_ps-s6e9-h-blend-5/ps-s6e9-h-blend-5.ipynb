# %% [markdown]
# ## [Predicting Electric Vehicle Purchases](https://www.kaggle.com/competitions/playground-series-s6e9/code?competitionId=125219&sortBy=scoreDescending&excludeNonAccessedDatasources=true)
#
# &nbsp;
#
# &nbsp; **We apologize**! - there was an inconspicuous error in the [PS-s6e9 | h-blend (3)](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-3/) notebook (inconspicuous because we didn't actually use that specific data—or, to be more precise, we used it after a write-read cycle, and the writing process itself was correct). In the call to `h_blend_hs(...)`, you need to replace `df_sample` with `df_sample.copy()`!
#
# &nbsp;
#
# Playground Series - Season 6 Episode 9
#
#
# | |  | | public | &nbsp; | | &nbsp; | &nbsp; | &nbsp; |
# |:-|:-:|:-:|:-:| :-: | :-: | :-: | :-: | :-: |
# ||||||Group.**A**||
# | **1**. |||[0.94_621](https://www.kaggle.com/code/yekenot/ps-s6-e9-realmlp-pytorch?scriptVersionId=349387299)|&nbsp;v.3&nbsp;| [PS.S6.E9: RealMLP · PyTorch](https://www.kaggle.com/code/yekenot/ps-s6-e9-realmlp-pytorch/notebook) | master  | [Vladimir Demidov](https://www.kaggle.com/yekenot) | Russia |
# | **2**. |||[0.94_637](https://www.kaggle.com/code/najiama/pure-lgbm-model-cv-0-94606-lb-0-94637?scriptVersionId=348048466)|&nbsp;v.1&nbsp;| [Pure LGBM Model CV 0.94606 LB 0.94637](https://www.kaggle.com/code/najiama/pure-lgbm-model-cv-0-94606-lb-0-94637) | expert  | [Naji](https://www.kaggle.com/najiama) | Brazil |
# | **3**. |||[0.94_639](https://www.kaggle.com/code/najiama/xgboost-triple-te-dynamic-pruning-lb-0-94639/notebook)|&nbsp;v.1&nbsp;| [XGBoost . Triple-TE & Dynamic Pruning (LB 0.94639)](https://www.kaggle.com/code/najiama/xgboost-triple-te-dynamic-pruning-lb-0-94639?scriptVersionId=349376806) | expert  | [Naji](https://www.kaggle.com/najiama) | Brazil |
# || | | [**0.94_644**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349663609) | &nbsp; &nbsp; [**v**.**1**](#v.1) &nbsp; &nbsp;  |[ **1**. **2**. **3**.] . [ 0.30 + 0.30 + 0.40 ] | 30 x 70 |[ +0.058, -0.021,-0.037 ]|
# ||||||Group.**B**||
# | **4**. |||[0.94_607](https://www.kaggle.com/code/jazivxt/single-model-zoom-zoom?scriptVersionId=347208305)|&nbsp;v.1&nbsp;| [Single Model - Zoom Zoom](https://www.kaggle.com/code/jazivxt/single-model-zoom-zoom) | grandmaster | [jazivxt](https://www.kaggle.com/jazivxt) | United States |
# | **5**. |||[0.94_614](https://www.kaggle.com/code/sumitsarkar969/catboost-playground-series-s6e9?scriptVersionId=349123971)|&nbsp;v.8&nbsp;| [Catboost . Playground Series - S6E9](https://www.kaggle.com/code/sumitsarkar969/catboost-playground-series-s6e9) | contributor | [Sumit Sarkar](https://www.kaggle.com/sumitsarkar969) | India |
# | **6**. |||[0.94_638](https://www.kaggle.com/code/mikhailnaumov/electric-vehicle-purchases-single-xgb?scriptVersionId=348328268)|&nbsp;v.3&nbsp;| [Electric Vehicle Purchases . XGB](https://www.kaggle.com/code/mikhailnaumov/electric-vehicle-purchases-xgb) | master  | [Mikhail Naumov](https://www.kaggle.com/mikhailnaumov) | World |
# || | | [**0.94_636**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349665701) | &nbsp; &nbsp; [**v**.**2**](#v.2) &nbsp; &nbsp;  |[ **4**. **5**. **6**.] . [ 0.20 + 0.20 + 0.60 ] | 30 x 70 |[ +0.058, -0.021,-0.037 ]|
# ||||||Group.**C**||
# | **7**. |||[0.94_601](https://www.kaggle.com/code/lucifer19/ev-quantum-forge-s6e9-xgboost/notebook?scriptVersionId=346769553)|&nbsp;v.7&nbsp;| [EV Quantum Forge S6E9 XGBoost](https://www.kaggle.com/code/lucifer19/ev-quantum-forge-s6e9-xgboost/notebook) | master | [Krizsó Gergely](https://www.kaggle.com/lucifer19) | Hungary |
# | **8**. |||[0.94_620](https://www.kaggle.com/code/amanatar/s6e9-standalone-histgradientboosting?scriptVersionId=348751601)|&nbsp;v.4&nbsp;| [S6E9: Standalone HistGradientBoosting](https://www.kaggle.com/code/amanatar/s6e9-standalone-histgradientboosting) | expert  | [Aman Atar](https://www.kaggle.com/amanatar) | India |
# | **9**. |||[0.94_639](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-high-speed?scriptVersionId=348114291)|&nbsp;v.18&nbsp;| [PS-s6e9 . h-blend (high-speed)](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-high-speed?scriptVersionId=348114291) | grandmaster | [F.A.Nina](https://www.kaggle.com/nina2025) | Georgia |
# || | | [**0.94_637**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349668310) | &nbsp; &nbsp; [**v**.**3**](#v.3) &nbsp; &nbsp;  |[ **7**. **8**. **9**.] . [ 0.10 + 0.20 + 0.70 ] | 30 x 70 |[ +0.058, -0.021,-0.037 ]|
# ||||||Group.**D**||
# | **10**. |||[0.94_609](https://www.kaggle.com/code/pranjalverma08/predicting-ev-adpotion?scriptVersionId=347642881)|&nbsp;v.5&nbsp;| [Predicting EV Adpotion](https://www.kaggle.com/code/pranjalverma08/predicting-ev-adpotion/notebook) | master | [Pranjal Verma](https://www.kaggle.com/pranjalverma08) | India
# | **11**. |||[0.94_609](https://www.kaggle.com/code/maiernator/s6e9-ctboost-not-catboost-astra-baseline?scriptVersionId=347343558)|&nbsp;v.1&nbsp;| [S6E9 CTBoost(not catboost) Astra baseline](https://www.kaggle.com/code/maiernator/s6e9-ctboost-not-catboost-astra-baseline) | expert  | [Markus.JM](https://www.kaggle.com/maiernator) | Germany |
# | **12**. |||[0.94_611](https://www.kaggle.com/code/yekenot/ps-s6-e9-realmlp-pytorch?scriptVersionId=348364380)|&nbsp;v.2&nbsp;| [PS.S6.E9: RealMLP · PyTorch](https://www.kaggle.com/code/yekenot/ps-s6-e9-realmlp-pytorch/notebook) | master  | [Vladimir Demidov](https://www.kaggle.com/yekenot) | Russia |
# || | | [**0.94_631**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349670235) | &nbsp; &nbsp; [**v**.**4**](#v.4) &nbsp; &nbsp;  |[ **10**. **11**. **12**.] . [ 0.20 + 0.30 + 0.50 ] | 30 x 70 |[ +0.058, -0.021,-0.037 ]|
# |||||||||
# ||||| | [ **participiants** ] . [ **weights** ] |asc/desc|**correct weight**||
# || | | [**0.94_641**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349672364) | &nbsp; &nbsp; [**v**.**5**](#v.5) &nbsp; &nbsp;  |[ **A**. **B**. **C**. **D**.] . [ 0.25 + 0.25 + 0.25 + 0.25 ] | 30 x 70 |[+0.074,-0.009,-0.024,-0.041]|
# || | | [**0.94_643**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349674446) | &nbsp; &nbsp; [**v**.**6**](#v.6) &nbsp; &nbsp;  |[ **A**. **B**. **C**. **D**.] . [ 0.50 + 0.20 + 0.20 + 0.10 ] | 30 x 70 |[+0.074,-0.009,-0.024,-0.041]|
# || | | [**0.94_643**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349676753) | &nbsp; &nbsp; [**v**.**7**](#v.7) &nbsp; &nbsp;  |[ **A**. **B**. **C**. **D**.] . [ 0.65 + 0.15 + 0.15 + 0.05 ] | 30 x 70 |[-0.041,-0.024,-0.009,+0.074]|
# || | | [**0.94_643**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349682032) | &nbsp; &nbsp; [**v**.**8**](#v.8) &nbsp; &nbsp;  |[ **A**. **B**. **C**. **D**.] . [ 0.79 + 0.07 + 0.07 + 0.07 ] | 30 x 70 |[+0.074,-0.009,-0.024,-0.041]|
# |||||||||
# || | | [**0.94_650**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349699144) | &nbsp; &nbsp; [**v**.**11**](#Version.11) &nbsp; &nbsp; |[ v.? + [EV blend ⚡](https://www.kaggle.com/code/nathaliach/ev-blend?scriptVersionId=349595833) ] . [ 0.015 + 0.985 ] | rank |[ - ]|
# || | | [?]() | &nbsp; &nbsp; [**v**.**12**](#Version.12) &nbsp; &nbsp;  |[a1+a2+a3+c9-c8-b5] . [30+20+40+20-5-5]% | 30 x 70 |[+0.07,+0.04,-0.01,-0.02,-0.03,-0.05]|

# %%
import numpy as np, polars as pl
import os,ast,copy, pandas as pd, shutil, matplotlib.pyplot as plt, seaborn as sns
import warnings; warnings.filterwarnings('ignore')

# An example of working with Seaborn is taken from a notebook:
# https://www.kaggle.com/code/likithagedipudi/kaggle-success-factors
# Presented by an expert from Buffalo, New York, United States - Likitha Gedipudi
# https://www.kaggle.com/likithagedipudi

from bokeh.plotting import figure, gridplot 
from bokeh.io import output_file, show, output_notebook
output_notebook()

def seaborn_display_1(params, df_cross):
    
    colors = [subm['color'] for subm in params['subm']]
    
    def dossier(js,subms,cols):
        def quant(i,js,subms,cols):
            return {"c" : i, "q" : sum([1 for subm in cols[i] if subm == subms[js]])}
        return {
            'name' : subms[js],
            'q_in' : [quant(i,js,subms,cols) for i in range(len(subms))]
        }
    alls = pd.read_csv(f'tida_desc.csv')
    matrix = [ast.literal_eval(str(row.alls)) for row in alls.itertuples()]
    subms = sorted(matrix[0])
    cols = [[data[i] for data in matrix] for i in range(len(subms))]
    df_subms = pd.DataFrame({f'col_{i}': [x[i] for x in matrix] for i in range(len(subms))})
    dossiers = [dossier(js,subms,cols) for js in range(len(subms))]
    subm_names = [one_dossier['name'] for one_dossier in dossiers]
    
    nqs,qss,i = [],[],0
    
    for one_dossier in dossiers: 
        qs = [one['q'] for one in one_dossier['q_in']]
        x_names = [name.replace("Group","").replace("subm_","") for name in subm_names]
        qss.append(qs)
        nqs.append({'n':x_names, 'q':qs})
        i+=1
    
    plt.style.use('seaborn-v0_8-whitegrid')
    plt.rcParams['font.size']      = 7
    plt.rcParams['axes.titlesize'] = 9
    plt.rcParams['axes.labelsize'] = 8

    len_nqs = len(nqs) if len(nqs) > 3 else 4

    fig, axes = plt.subplots(2, len_nqs, figsize=(2.1*len_nqs, 4))
    
    def ric(j, i, n, q, colors):
        ax1 = axes[j, i]
        bars1 = ax1.bar(n, q, color=colors)
        ax1.set_title(f'ratios in alls.col {i}', fontweight='bold')
        ax1.set_xticklabels(n, rotation=45, ha='right')
        i = 0
        for bar, val in zip(bars1, q):
            if i != 0:
                ax1.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 50, 
                         f'{val:,.0f}', ha='center', va='bottom', fontsize=8)
            i += 1

    lm_max = 0
    for i in range(len(nqs)):
        for q in nqs[i]['q']:
            if q > lm_max: lm_max = q  
    lm_colors = ['whitesmoke'] + colors
    for nq in nqs:
        nq['n'].insert(0,'')
        nq['q'].insert(0, lm_max*1.13)

    for i in range(len(nqs)): ric(0, i, nqs[i]['n'], nqs[i]['q'], lm_colors)

    ax10 = axes[1, 0]
    #--------------------------------------------------------------------------------
    sub_wts = params['subwts']
    main_wts = [subm['weight'] for subm in params['subm']]
    mms,acc_mass = [],[]
    for j in range(len(dossiers)):
        one_dossier = dossiers[j]
        qs = [one['q'] for one in one_dossier['q_in']]
        mm = [qs[h] * (main_wts[j] + sub_wts[h]) for h in range(len(sub_wts))]
        mass = sum(mm)
        mms.append(mm)
        acc_mass.append(round(mass))
    acc_mass = acc_mass
    y_names = [str(mass) + " - " + name for name,mass in zip(subm_names,acc_mass)]
    colors  .insert(0,'whitesmoke')
    y_names .insert(0,'')
    acc_mass.insert(0, max(acc_mass) * 1.13)
    irbis = ax10.barh(y_names[::-1], acc_mass[::-1], color=colors[::-1])
    ax10.set_title('relations of g.masses', fontweight='bold')
    ax10.set_xlabel('weights')

    ax11 = axes[1, 1]
    #--------------------------------------------------------------------------------
    corr_matrix = alls[subm_names].corr()
    mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
    mask = 0.5*mask
    sns.heatmap(corr_matrix, mask=mask, annot=True, cmap='RdBu_r', 
                center=0,fmt='.3f', square=True, linewidths=0.5, ax=ax11,
                cbar_kws={'shrink': 0.8})
    ax11.set_title('Correlation Matrix', fontweight='bold', fontsize=9)
    ax11.set_xticklabels(subm_names, rotation=45, ha='right')

    ax13 = axes[1,3]
    #--------------------------------------------------------------------------------
    ip1 = len(nqs)-4
    ip2 = len(nqs)-2
    sample  = alls.sample(min(100_000, len(alls)), random_state=42)
    scatter = ax13.scatter(np.log10(sample[subm_names[ip2]] + 1), 
                           np.log10(sample[subm_names[ip1]] + 1), 
                           c=sample[params['id_target'][1]], cmap='viridis', alpha=0.5,s=10)
    ax13.set_title(f'{subm_names[ip2]} vs {subm_names[ip1]}', fontweight='bold', fontsize=8)
    plt.colorbar(scatter, ax=ax13, label='Score')

    if len(nqs) >= 5:
        ax14 = axes[1,4]
        #----------------------------------------------------------------------------
        ip1 = len(nqs)-1
        ip2 = len(nqs)-2
        sample  = alls.sample(min(100_000, len(alls)), random_state=42)
        scatter = ax14.scatter(np.log10(sample[subm_names[ip2]] + 1), 
                               np.log10(sample[subm_names[ip1]] + 1), 
                               c=sample[params['id_target'][1]], cmap='viridis', alpha=0.5,s=10)
        ax14.set_title(f'{subm_names[ip2]} vs {subm_names[ip1]}', fontweight='bold', fontsize=8)
        plt.colorbar(scatter, ax=ax14, label='Score')

    ax12 = axes[1, 2]
    #--------------------------------------------------------------------------------
    colors = [subm['color'] for subm in params['subm']]
    
    for subm,color in zip(subm_names,colors):
        subm_data = alls[subm]
        ax12.hist(np.log10(subm_data + 1), bins=30, alpha=0.5, label=subm, color=color)
    ax12.set_title('(Log Scale)', fontweight='bold')
    ax12.set_xlabel('log10')
    ax12.set_ylabel('Frequency')
    ax12.legend()
 
    plt.tight_layout()
    plt.show()


def matrix_vs(path,fs_names, params):
    _id     = params['id_target'][0]
    _target = params['id_target'][1]
    def load(path,fs_names):
        dfs = [pd.read_csv(path + name_subm +'.csv') for name_subm in fs_names]
        for i in range(len(dfs)):
            dfs[i] = dfs[i].rename(columns={_target: f'{fs_names[i]}'})
        dfsm = pd.merge(dfs[0], dfs[1], on=_id)
        for i in range(2,len(dfs)):
            dfsm = pd.merge(dfsm,dfs[i],on=_id)
        return dfsm   
    def make_list_vs(fs_names):
        list = []
        for i in range(0,len(fs_names)-1):
            for j in range(i+1,len(fs_names)):
                list.append(fs_names[i] + "_vs_" + fs_names[j])
        return list
    def get_mvs(dfs, list_vs):
        def get_abs_distance(x,t1,t2):
            return abs(x[t1]-x[t2])
        for vs in list_vs:
            t = vs.split('_vs_')
            dfs[vs] = dfs.apply(lambda x: get_abs_distance(x,t[0],t[1]), axis=1)
        return dfs   
    def distance_vs(name, st_names, list_vs, dfs):
        distances = []
        for st in st_names:
            vs_between = name + "_vs_" + st
            if vs_between not in list_vs:
                distances.append(0)
            else: distances.append(round(dfs[vs_between].sum()))
        return distances
    dfs = load(path,fs_names)
    list_vs = make_list_vs(fs_names)
    mvs = get_mvs(dfs, list_vs)
    m1 = pd.DataFrame({'subm':fs_names})
    m2 = pd.DataFrame({ name :distance_vs(name, fs_names, list_vs, mvs) for name in fs_names})
    matrix = pd.concat([m1,m2],axis=1)
    return matrix


def display_distances(params):
    files = [subm['name'] for subm in params['subm']]
    distances = matrix_vs ( params['path'], files, params )            
    display(distances)


def seaborn_display_2(params, file_name_cross=""):
    display_distances(params)
    plt.figure(figsize=(9, 2.5))
    for subm in params['subm']:
        pred = pd.read_csv(params['path']+subm['name']+'.csv')[params['id_target'][1]]
        sns.kdeplot(pred, label = subm['name'], linewidth = 0.5)
    if file_name_cross != '':
        pred = pd.read_csv(file_name_cross)[params['id_target'][1]]
        sns.kdeplot(pred, label = 'blend', linewidth = 1, linestyle = 'dashed')
    plt.title("KDE")
    plt.xlabel("target")
    plt.ylabel("Density")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()


def h_blend( params, _update={}, show_details=False, subm=''):    
    if _update != {}: params.update(_update)
    file_short_names = [subm['name'] for subm in params['subm']]
    _id,_target = params['id_target'][0], params['id_target'][1]
    
    def read(params,i):
        target_new_name = params["subm"][i]["name"]
        file_subm = params["path"] + target_new_name + ".csv"
        df = pl.read_csv(file_subm).rename({_target:target_new_name})
        return df 
        
    def merge(dfs_subm):
        df_subms =  dfs_subm[0].join(dfs_subm[1], on=[_id], how="inner")
        for i in range(2, len(params["subm"])): 
            df_subms = df_subms.join(dfs_subm[i], on=[_id], how="inner")
        return df_subms
        
    def da(params, show_details, sorting_direction):
        
        df_subms = merge([read(params,i) for i in range(len(params["subm"]))])
        cols = [col for col in df_subms.columns if col != _id]
        short_name_cols = [c for c in cols]
            
        def summa(x,cs,wts,ic_alls): 
            return sum([x[cs[j]] * (wts[0][j] + wts[1][ic_alls[j]]) for j in range(len(cs))])
         
        correct = [wt for wt in params["subwts"]]
        weights = [subm['weight'] for subm in params["subm"]]
        
        def f_corr(x, cs=cols, w=weights, cw=correct):
            ic = [x['alls'].index(c) for c in short_name_cols]
            cS = [x[cols[j]] * (w[j] + cw[ic[j]]) for j in range(len(cols))]
            return sum(cS)
            
        def f_alls(x, sd=sorting_direction,cs=cols):
            tes = {c: x[c] for c in cs}.items()
            return [t[0] for t in sorted(tes,key=lambda k:k[1],reverse=sd=='desc')]

        df_subms = df_subms.with_columns(
            pl.struct(cols)         .map_elements(lambda x: f_alls(x))
            .alias("alls"),
        )
        df_subms = df_subms.with_columns(
            pl.struct(cols+['alls']).map_elements(lambda x: f_corr(x), return_dtype=pl.Float32)
            .alias(sorting_direction)
        )
        df_subms = df_subms.rename({c:nc for c,nc in zip(cols, short_name_cols)})

        if sorting_direction=='desc': 
            return df_subms, params['type_sort'][2]
        if sorting_direction=='asc': 
            return df_subms, params['type_sort'][1]

    def pandas_save(polars_df, params=params, filename='tida_desc.csv'):
        pandas_df = polars_df.to_pandas()
        pandas_df['alls'] = pandas_df.apply(lambda x:str(x['alls']).replace(' ',' ,'),axis=1)
        pandas_df . to_csv(filename, index=False)
            
    def ensemble (params, show_details): 
        dfD, wtsD = da(params, show_details,'desc')
        dfA, wtsA = da(params, show_details,'asc')
        dfA = dfA[['id','asc']]
        dfj = dfD.join(dfA, on="id", how="left")
        dfe = dfj.with_columns((pl.col("desc") *wtsD + wtsA* pl.col("asc")).alias(_target))
        pandas_save(dfe, params=params)
        if show_details: 
            display(dfe.head(4))
        return dfe[[_id,_target]]
    
    df = ensemble(params, show_details)
    if subm != '': df.write_csv(subm)
    if show_details == 'seaborn':
        seaborn_display_1(params, df)
        seaborn_display_2(params, file_name_cross=subm)
    return df


def h_blend_hs(params, df_sample, target): 
    
    def read_data(subm_name):
        return pd.read_csv(params['path']+subm_name+'.csv')[params['id_target'][1]]

    subms_datas = [{'subm_name':read_data(subm['name'])} for subm in params['subm']]
    matrix      = np.vstack([subm_one_data['subm_name'] for subm_one_data in subms_datas]).T
    main_wts    = np.asarray([subm['weight'] for subm in params['subm']], dtype=float)
    correct_wts = np.asarray(params['subwts'], dtype=float)

    def side(reverse):
        order = np.argsort(-matrix if reverse else matrix, axis=1)
        out = np.zeros(matrix.shape[0], dtype=float)
        for rank_idx in range(matrix.shape[1]):
            col_idx = order[:, rank_idx]
            new_weights = main_wts[col_idx] + correct_wts[rank_idx]
            out += matrix[np.arange(matrix.shape[0]), col_idx] * new_weights
        return out

    ASC_,DESC_ = side(False),side(True)

    df_sample[target] = ASC_*params['type_sort'][1] + DESC_*params['type_sort'][2]

    return df_sample

# %%
pkw   = '/kaggle/working/'
pds10 = '/kaggle/input/datasets/nina2025/ps-s6e9-10/'
pds13 = '/kaggle/input/datasets/nina2025/ps-s6e9-13/'

target = 'Will_Buy_EV'

sam = pd.read_csv('/kaggle/input/competitions/playground-series-s6e9/sample_submission.csv')

# %%
shutil.copy(pds13+'0.94621.csv',  pkw+'a1.csv')
shutil.copy(pds10+'0.94637.csv',  pkw+'a2.csv')
shutil.copy(pds13+'0.94639.csv',  pkw+'a3.csv')

shutil.copy(pds10+'0.94607_b.csv',pkw+'b4.csv')
shutil.copy(pds13+'0.94614.csv',  pkw+'b5.csv')
shutil.copy(pds10+'0.94638.csv',  pkw+'b6.csv')

shutil.copy(pds10+'0.94601.csv',  pkw+'c7.csv')
shutil.copy(pds13+'0.94620.csv',  pkw+'c8.csv')
shutil.copy(pds10+'0.94639.csv',  pkw+'c9.csv')

shutil.copy(pds10+'0.94609_c.csv',pkw+'d10.csv')
shutil.copy(pds10+'0.94609_d.csv',pkw+'d11.csv')
shutil.copy(pds10+'0.94611.csv',  pkw+'d12.csv')

# %%
# %%time

params_A = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ 0.058, -0.021, -0.037 ],
  'subm'     : [ 
      {'name': f'a1','weight':0.30},
      {'name': f'a2','weight':0.30},
      {'name': f'a3','weight':0.40},
]}
df_A = h_blend_hs(params_A,sam.copy(),target);df_A.to_csv(pkw+'Group_A.csv',index=False)
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
params_B = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ 0.058, -0.021, -0.037 ],
  'subm'     : [ 
      {'name': f'b4','weight':0.20},
      {'name': f'b5','weight':0.20},
      {'name': f'b6','weight':0.60},
]}
df_B = h_blend_hs(params_B,sam.copy(),target);df_B.to_csv(pkw+'Group_B.csv',index=False)
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
params_C = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ 0.058, -0.021, -0.037 ],
  'subm'     : [ 
      {'name': f'c7','weight':0.10},
      {'name': f'c8','weight':0.20},
      {'name': f'c9','weight':0.70},
]}
df_C = h_blend_hs(params_C,sam.copy(),target);df_C.to_csv(pkw+'Group_C.csv',index=False)
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
params_D = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ 0.058, -0.021, -0.037 ],
  'subm'     : [ 
      {'name': f'd10','weight':0.20},
      {'name': f'd11','weight':0.30},
      {'name': f'd12','weight':0.50},
]}
df_D = h_blend_hs(params_D,sam.copy(),target);df_D.to_csv(pkw+'Group_D.csv',index=False)
# ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~ ~
print(df_A,'\n',df_B,'\n',df_C,'\n',df_D,'\n')

# %%
for file in 'Group_A,Group_B,Group_C,Group_D'.split(','): 
    if os.path.isfile(file+'.csv'): print(pl.read_csv(file+'.csv'))

# %% [markdown]
# ## v.1
#
# ### LB = [**0.94_644**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349663609)

# %%
# %%time

params = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ 0.058, -0.021, -0.037 ],
  'subm'     : [ 
      {'name': f'a1', 'weight':0.30, 'color':'navy'},
      {'name': f'a2', 'weight':0.30, 'color':'darkorange'},
      {'name': f'a3', 'weight':0.40, 'color':'darkgreen'},
]}
df1 = h_blend(params, show_details='seaborn', subm='cross.csv')

df1 . write_csv("df1.csv")   ;print(df1)

# %% [markdown]
# ## v.2
#
# ### LB = [**0.94_636**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349665701)

# %%
# %%time

params = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ 0.058, -0.021, -0.037 ],
  'subm'     : [ 
      {'name': f'b4', 'weight':0.20, 'color':'navy'},
      {'name': f'b5', 'weight':0.20, 'color':'darkorange'},
      {'name': f'b6', 'weight':0.60, 'color':'darkgreen'},
]}
df2 = h_blend(params, show_details='seaborn', subm='cross.csv')
print(df2)

# %% [markdown]
# ## v.3
#
# ### LB = [**0.94_637**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349668310)

# %%
# %%time

params = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ 0.058, -0.021, -0.037 ],
  'subm'     : [ 
      {'name': f'c7', 'weight':0.10, 'color':'navy'},
      {'name': f'c8', 'weight':0.20, 'color':'darkorange'},
      {'name': f'c9', 'weight':0.70, 'color':'darkgreen'},
]}
df3 = h_blend(params, show_details='seaborn', subm='cross.csv')
print(df3)

# %% [markdown]
# ## v.4
#
# ### LB = [**0.94_631**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349670235)

# %%
# %%time

params = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ 0.058, -0.021, -0.037 ],
  'subm'     : [ 
      {'name': f'd10', 'weight':0.20, 'color':'navy'},
      {'name': f'd11', 'weight':0.30, 'color':'darkorange'},
      {'name': f'd12', 'weight':0.50, 'color':'darkgreen'},
]}
df4 = h_blend(params, show_details='seaborn', subm='cross.csv')
print(df4)

# %% [markdown]
# ## v.5
#
# ### LB = [**0.94_641**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349672364)

# %%
# %%time

params = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ +0.074, -0.009,-0.024,-0.041 ],
  'subm'     : [       
      {'name': f'Group_A', 'weight':0.25, 'color':'navy'},
      {'name': f'Group_B', 'weight':0.25, 'color':'darkorange'},
      {'name': f'Group_C', 'weight':0.25, 'color':'darkgreen'},
      {'name': f'Group_D', 'weight':0.25, 'color':'crimson'},
]}
df5 = h_blend(params, show_details='seaborn', subm='cross.csv')
print(df5)

# %% [markdown]
# ## v.6
#
# ### LB = [**0.94_643**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349674446)

# %%
params = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ +0.074, -0.009,-0.024,-0.041 ],
  'subm'     : [       
      {'name': f'Group_A', 'weight':0.50, 'color':'navy'},
      {'name': f'Group_B', 'weight':0.20, 'color':'darkorange'},
      {'name': f'Group_C', 'weight':0.20, 'color':'darkgreen'},
      {'name': f'Group_D', 'weight':0.10, 'color':'crimson'},
]}
df6 = h_blend(params, show_details='seaborn', subm='cross.csv')
print(df6)

# %% [markdown]
# ## v.7
#
# ### LB = [**0.94_643**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349676753)

# %%
params = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ -0.041,-0.024,-0.009,+0.074 ],
  'subm'     : [       
      {'name': f'Group_A', 'weight':0.65, 'color':'navy'},
      {'name': f'Group_B', 'weight':0.15, 'color':'darkorange'},
      {'name': f'Group_C', 'weight':0.15, 'color':'darkgreen'},
      {'name': f'Group_D', 'weight':0.05, 'color':'crimson'},
]}
df7 = h_blend(params, show_details='seaborn', subm='cross.csv')
print(df7)

# %% [markdown]
# ## v.8
#
# ### LB = [**0.94_643**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349682032)

# %%
params = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ +0.074, -0.009,-0.024,-0.041 ],
  'subm'     : [       
      {'name': f'Group_A', 'weight':0.79, 'color':'navy'},
      {'name': f'Group_B', 'weight':0.07, 'color':'darkorange'},
      {'name': f'Group_C', 'weight':0.07, 'color':'darkgreen'},
      {'name': f'Group_D', 'weight':0.07, 'color':'crimson'},
]}
df8 = h_blend(params, show_details='seaborn', subm='cross.csv')
print(df8)

# %% [markdown]
# ## Version.11
#
# ### LB = [**0.94_650**](https://www.kaggle.com/code/nina2025/ps-s6e9-h-blend-5?scriptVersionId=349699144)

# %%
df1      = '/kaggle/working/df1.csv'
path     = '/kaggle/input/notebooks/nathaliach/ev-blend/submission.csv'

EV_blend = pd.read_csv(path).set_index('id')['Will_Buy_EV']
hb_cross = pd.read_csv(df1) .set_index('id')['Will_Buy_EV'].reindex(EV_blend.index)

from scipy.stats import rankdata

rank = lambda s: pd.Series(rankdata(s) / len(s), index=s.index)

rank_cross, rank_EV_blend = rank(hb_cross), rank(EV_blend)

data =  rank_cross * 0.015 + 0.985 * rank_EV_blend 

print(hb_cross,"\n\n",EV_blend,"\n\n-------\n\n",rank_cross,"\n\n",rank_EV_blend)

df11 = pd.DataFrame({'id': data.index, 'Will_Buy_EV': data.to_numpy()})

# %% [markdown]
# ## Version.12
#
# ### LB = [?]()

# %%
params = {
  'path'     : pkw,
  'id_target': ['id', 'Will_Buy_EV'],
  'type_sort': ['asc/desc', 0.30, 0.70 ],
  'subwts'   : [ +0.07,+0.04,-0.01,-0.02,-0.03,-0.05 ],
  'subm'     : [ 
      {'name': f'a1', 'weight':+0.30, 'color':'navy'},
      {'name': f'a2', 'weight':+0.20, 'color':'darkorange'},
      {'name': f'a3', 'weight':+0.40, 'color':'darkgreen'},
      {'name': f'c9', 'weight':+0.20, 'color':'crimson'},
      {'name': f'c8', 'weight':-0.05, 'color':'darkmagenta'},
      {'name': f'b5', 'weight':-0.05, 'color':'firebrick'},
]}
df12 = h_blend(params, show_details='seaborn', subm='cross.csv')
print(df12)

# %%
for file in 'a1,a2,a3,b4,b5,b6,c7,c8,c9,d10,d11,d12'.split(','): 
    if os.path.isfile(file+'.csv'): os.remove(file+'.csv')

for file in 'Group_A,Group_B,Group_C,Group_D,df1,cross,tida_desc'.split(','): 
    if os.path.isfile(file+'.csv'): os.remove(file+'.csv')

# %% [markdown]
# ## Submit

# %%
df = df1  # LB=0.94644 \
df = df2  # LB=0.94636  \ 
df = df3  # LB=0.94637   \
df = df4  # LB=0.94631    \
                          # polars df.write_csv('submission.csv')
df = df5  # LB=0.94641    /
df = df6  # LB=0.94643   /
df = df7  # LB=0.94643  /
df = df8  # LB=0.94643 / 

df = df11 # LB=0.94650    # pandas df.to_csv('submission.csv',index=False)

df = df12 # LB=?

# %%
df.write_csv('submission.csv')
df
